# %%
import pandas as pd
df = pd.read_csv("Untitled spreadsheet - Sheet1 (1).csv")
df
# Out:
#     Review ID  Rating                                             Review  \
# 0           1       1  delivery is funded by shop keeper not by custo...
# 1           2       3                                               Nice
# 2           3       4                                              super
# 3           4       4                                               good
# 4           5       4             Fast delivery. Overall Good. Thank you
# 5           6       4  cod is not working. that's the on!y issue othe...
# 6           7       1  I dont know how this platform has got 4.3 rati...
# 7           8       5  i have been ordering for quite a while now...t...
# 8           9       5                 I just like how smoothly it worked
# 9          10       4  It all depends on your delivery boy. So please...
# 10         11       5  very niuce app but not installed tilll yet oop...
# 11         12       1  why are your was not download there please dow...
# ...
